# %%
import cv2
import pytesseract
import os

# read the image file
img = cv2.imread(r'/home/sunil/Desktop/np/uploads/car-service.png')

# convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# apply thresholding
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# recognize text with Pytesseract
text = pytesseract.image_to_string(thresh)

# print the recognized text
print(text)
# Out:
# g Service Receipt
#
# 04/13/2020
# AUTOTECH SERVICE CENTER - 8980 West Lake Pond Dr. Long Beach, CA 90813
# Bill To
# Michael Carlsmilth
# (958) 2035829
# michael@example.com
# 123 Rodeo Drive, 213 Mark Street
# Great City, Some State, 1111
# United States.
# Car Make Car Model YearModel  Color Transmission Engine Type
# BMW 3161 1999 Red  Automatic Gas
# Last Change Oil Mileage Reading Next Change Ol
# Apr 13,2020 99000 04/13/2021
# Under Chassis Hood
# Tie Rod Ends, Idler Arm Belts, Spark plugs, Oil, ATF
# Brakes Bearing and Shocks
# Wheel Cylinder
# Materials Labor
# Particulars ‘Amount Particulars ‘Amount
# Oil Filter 20 Change Oil 50
# Synthetic Ol 200 belt replacement 100
# Spark plugs 100
#
# Total Labor Cost $150
#
# Total Material Cost  $320
#
# Total Cost $470

# %%
# !pip install PIL
pip install pytesseract
pip install pdf2image
sudo apt-get install tesseract-ocr
# Out:
#   Cell In[8], line 2
#     pip install pytesseract
#         ^
# SyntaxError: invalid syntax

# %%
import platform
from tempfile import TemporaryDirectory
from pathlib import Path
 
import pytesseract
from pdf2image import convert_from_path
from PIL import Image

# %%
# !pip install pdf2image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pdf2image-1.16.3-py3-none-any.whl (11 kB)
# ...

# %%
import pdf2image 

pages = convert_from_path(r'/home/sunil/Desktop/download.pdf')

for i in range(len(pages)):

    pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pdf2image/pdf2image.py:589, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588 if "Pages" not in d:
# --> 589     raise ValueError
#     591 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pdf2image
# ----> 3 pages = convert_from_path(r'/home/sunil/Desktop/download.pdf')
#       5 for i in range(len(pages)):
#       7     pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
#
# ...

# %%
# import module
from pdf2image import convert_from_path


# Store Pdf with convert_from_path function
images = convert_from_path('/home/sunil/Desktop/download.pdf')

for i in range(len(images)):

# Save pages as images in the pdf
    images[i].save('page'+ str(i) +'.jpg', 'JPEG')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pdf2image/pdf2image.py:589, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588 if "Pages" not in d:
# --> 589     raise ValueError
#     591 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Cell In[15], line 6
#       2 from pdf2image import convert_from_path
#       5 # Store Pdf with convert_from_path function
# ----> 6 images = convert_from_path('/home/sunil/Desktop/download.pdf')
#       8 for i in range(len(images)):
#       9
#      10 # Save pages as images in the pdf
#      11     images[i].save('page'+ str(i) +'.jpg', 'JPEG')
#
# ...

# %%
import cv2
import pytesseract
import os

# read the image file
img = cv2.imread(r'/home/sunil/Desktop/practice_task/bill/reciept/bill_reciept/car-service.png')

# convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# apply thresholding
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# recognize text with Pytesseract
text = pytesseract.image_to_string(thresh)

# print the recognized text
print(text)
# Out:
#
#
# ‘pelt: Service Receipt
#
#
#
#
#
#
#
#
#
# 04/13/2020
# AUTOTECH SERVICE CENTER - 8980 West Lake Pond Dr. Long Beach, CA 90813
# TU Tey
# Michael Carlsmilth
# CPOE x)
# michael@example.com
# Dede eR USS
# Great City, Some State, 1111
# PU CeR cacy
# Orcs Cr rcy Rd TR)
# EI erry rrr} ComEd corny
# (eetecu te Dee) Next Change Oil
# Apr 13, 2020 ce 04/13/2021
# Teme y Ca]
# RT a Ca) Coe eee ee eg
# Brakes Bearing and Shocks
# Reed
# TEs Labor
# Particulars eu lane eu
# Gil Filter Pi) er zel 80
# Se CneT| Pn) Poe era are)
# See aay aC)
#
# Total Labor Cost SH
#
# Total Material Cost $320
#
# Total Cost $470

# %%
import string
text
a1 = text.lower()
a1
# Out:
# ' \n\n‘pelt: service receipt\n\n \n\n \n\n \n\n \n\n04/13/2020\nautotech service center - 8980 west lake pond dr. long beach, ca 90813\ntu tey\nmichael carlsmilth\ncpoe x)\nmichael@example.com\ndede er uss\ngreat city, some state, 1111\npu cer cacy\norcs cr rcy rd tr)\nei erry rrr} comed corny\n(eetecu te dee) next change oil\napr 13, 2020 ce 04/13/2021\nteme y ca]\nrt a ca) coe eee ee eg\nbrakes bearing and shocks\nreed\ntes labor\nparticulars eu lane eu\ngil filter pi) er zel 80\nse cnet| pn) poe era are)\nsee aay ac)\n\ntotal labor cost sh\n\ntotal material cost $320\n\ntotal cost $470\n\n \n\x0c'

# %%
import re

# %%
def remove_html_tags(text):
    pattern = re.compile('<?.*>')
    return pattern.sub(r'',a1)

# %%
a1
# Out:
# ' \n\n‘pelt: service receipt\n\n \n\n \n\n \n\n \n\n04/13/2020\nautotech service center - 8980 west lake pond dr. long beach, ca 90813\ntu tey\nmichael carlsmilth\ncpoe x)\nmichael@example.com\ndede er uss\ngreat city, some state, 1111\npu cer cacy\norcs cr rcy rd tr)\nei erry rrr} comed corny\n(eetecu te dee) next change oil\napr 13, 2020 ce 04/13/2021\nteme y ca]\nrt a ca) coe eee ee eg\nbrakes bearing and shocks\nreed\ntes labor\nparticulars eu lane eu\ngil filter pi) er zel 80\nse cnet| pn) poe era are)\nsee aay ac)\n\ntotal labor cost sh\n\ntotal material cost $320\n\ntotal cost $470\n\n \n\x0c'

# %%
# removing punctuation
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc(a):
    for char in exclude:
        aa = a1.replace(char,'')
    return aa

# %%
remove_punc(a)
# Out:
# ' \n\n‘pelt: service receipt\n\n \n\n \n\n \n\n \n\n04/13/2020\nautotech service center - 8980 west lake pond dr. long beach, ca 90813\ntu tey\nmichael carlsmilth\ncpoe x)\nmichael@example.com\ndede er uss\ngreat city, some state, 1111\npu cer cacy\norcs cr rcy rd tr)\nei erry rrr} comed corny\n(eetecu te dee) next change oil\napr 13, 2020 ce 04/13/2021\nteme y ca]\nrt a ca) coe eee ee eg\nbrakes bearing and shocks\nreed\ntes labor\nparticulars eu lane eu\ngil filter pi) er zel 80\nse cnet| pn) poe era are)\nsee aay ac)\n\ntotal labor cost sh\n\ntotal material cost $320\n\ntotal cost $470\n\n \n\x0c'

# %%
text.replace(" ", "")
# Out:
# '\n\n‘pelt:ServiceReceipt\n\n\n\n\n\n\n\n\n\n04/13/2020\nAUTOTECHSERVICECENTER-8980WestLakePondDr.LongBeach,CA90813\nTUTey\nMichaelCarlsmilth\nCPOEx)\nmichael@example.com\nDedeeRUSS\nGreatCity,SomeState,1111\nPUCeRcacy\nOrcsCrrcyRdTR)\nEIerryrrr}ComEdcorny\n(eetecuteDee)NextChangeOil\nApr13,2020ce04/13/2021\nTemeyCa]\nRTaCa)Coeeeeeeeg\nBrakesBearingandShocks\nReed\nTEsLabor\nParticularseulaneeu\nGilFilterPi)erzel80\nSeCneT|Pn)Poeeraare)\nSeeaayaC)\n\nTotalLaborCostSH\n\nTotalMaterialCost$320\n\nTotalCost$470\n\n\n\x0c'

# %%
exclude = string.punctuation

# %%
def remove_punc(text):
    for char in exclude:
        text = text.replace(char,'')
    return text

text
# Out:
# ' \n\n‘pelt: Service Receipt\n\n \n\n \n\n \n\n \n\n04/13/2020\nAUTOTECH SERVICE CENTER - 8980 West Lake Pond Dr. Long Beach, CA 90813\nTU Tey\nMichael Carlsmilth\nCPOE x)\nmichael@example.com\nDede eR USS\nGreat City, Some State, 1111\nPU CeR cacy\nOrcs Cr rcy Rd TR)\nEI erry rrr} ComEd corny\n(eetecu te Dee) Next Change Oil\nApr 13, 2020 ce 04/13/2021\nTeme y Ca]\nRT a Ca) Coe eee ee eg\nBrakes Bearing and Shocks\nReed\nTEs Labor\nParticulars eu lane eu\nGil Filter Pi) er zel 80\nSe CneT| Pn) Poe era are)\nSee aay aC)\n\nTotal Labor Cost SH\n\nTotal Material Cost $320\n\nTotal Cost $470\n\n \n\x0c'

# %%
from nltk import sent_tokenize,word_tokenize

# %%
# to lower_case
clean_text_1=[]
def to_lower(data):
    for words in text:
        clean_text_1.append(str.lower(words))
        
to_lower(text)

# %%
clean_text_1
# Out:
# [' ',
#  '\n',
#  '\n',
#  '‘',
#  'p',
#  'e',
#  'l',
#  't',
#  ':',
#  ' ',
#  's',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  ' ',
#  'r',
#  'e',
#  'c',
#  'e',
#  'i',
#  'p',
#  't',
#  '\n',
#  '\n',
#  ' ',
#  '\n',
#  '\n',
#  ' ',
#  '\n',
#  '\n',
#  ' ',
#  '\n',
#  '\n',
#  ' ',
#  '\n',
#  '\n',
#  '0',
#  '4',
#  '/',
#  '1',
#  '3',
#  '/',
#  '2',
#  '0',
#  '2',
#  '0',
#  '\n',
#  'a',
#  'u',
#  't',
#  'o',
#  't',
#  'e',
#  'c',
#  'h',
#  ' ',
#  's',
#  'e',
#  'r',
#  'v',
#  'i',
#  'c',
#  'e',
#  ' ',
#  'c',
#  'e',
#  'n',
#  't',
#  'e',
#  'r',
#  ' ',
#  '-',
#  ' ',
#  '8',
#  '9',
#  '8',
#  '0',
#  ' ',
#  'w',
#  'e',
#  's',
#  't',
#  ' ',
#  'l',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'p',
#  'o',
#  'n',
#  'd',
#  ' ',
#  'd',
#  'r',
#  '.',
#  ' ',
#  'l',
#  'o',
#  'n',
#  'g',
#  ' ',
#  'b',
#  'e',
#  'a',
#  'c',
#  'h',
#  ',',
#  ' ',
#  'c',
#  'a',
#  ' ',
#  '9',
#  '0',
#  '8',
#  '1',
#  '3',
#  '\n',
#  't',
#  'u',
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/sunil/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sent_tok = []
for sent in clean_text_1:
    sent = sent_tokenize(sent)
    sent_tok.append(sent)

# %%
sent_tok
# Out:
# [[],
#  [],
#  [],
#  ['‘'],
#  ['p'],
#  ['e'],
#  ['l'],
#  ['t'],
#  [':'],
#  [],
#  ['s'],
#  ['e'],
#  ['r'],
#  ['v'],
#  ['i'],
#  ['c'],
#  ['e'],
#  [],
#  ['r'],
#  ['e'],
#  ['c'],
#  ['e'],
#  ['i'],
#  ['p'],
#  ['t'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['0'],
#  ['4'],
#  ['/'],
#  ['1'],
#  ['3'],
#  ['/'],
#  ['2'],
#  ['0'],
#  ['2'],
#  ['0'],
#  [],
#  ['a'],
#  ['u'],
#  ['t'],
#  ['o'],
#  ['t'],
#  ['e'],
#  ['c'],
#  ['h'],
#  [],
#  ['s'],
#  ['e'],
#  ['r'],
#  ['v'],
#  ['i'],
#  ['c'],
#  ['e'],
#  [],
#  ['c'],
#  ['e'],
#  ['n'],
#  ['t'],
#  ['e'],
#  ['r'],
#  [],
#  ['-'],
#  [],
#  ['8'],
#  ['9'],
#  ['8'],
#  ['0'],
#  [],
#  ['w'],
#  ['e'],
#  ['s'],
#  ['t'],
#  [],
#  ['l'],
#  ['a'],
#  ['k'],
#  ['e'],
#  [],
#  ['p'],
#  ['o'],
#  ['n'],
#  ['d'],
#  [],
#  ['d'],
#  ['r'],
#  ['.'],
#  [],
#  ['l'],
#  ['o'],
#  ['n'],
#  ['g'],
#  [],
#  ['b'],
#  ['e'],
#  ['a'],
#  ['c'],
# ...

# %%
import pandas as pd
import numpy as np

# %%
text = pd.Series

# %%
text
# Out:
# pandas.core.series.Series

# %%
import tesseract
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3442 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 1
#     import tesseract
#
#   File ~/.local/lib/python3.11/site-packages/tesseract/__init__.py:34
#     print 'Creating user config file: {}'.format(_config_file_usr)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
