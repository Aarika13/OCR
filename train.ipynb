# %%
# ALl libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# # 1st datasets:

# %%
a= pd.read_csv(r'/home/sunil/Desktop/np/datasets/online_retail.csv')
a
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
a.shape
# Out:
# (541909, 8)

# %%
df1 = a.drop(["StockCode","CustomerID","Country"],axis=1)
df1
# Out:
#        InvoiceNo                          Description  Quantity  \
# 0         536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365                  WHITE METAL LANTERN         6
# 2         536365       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...                                  ...       ...
# 541904    581587          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice
# 0       2010-12-01 08:26:00       2.55
# 1       2010-12-01 08:26:00       3.39
# 2       2010-12-01 08:26:00       2.75
# ...

# %%
df1.shape
# Out:
# (541909, 5)

# %% [markdown]
# # 2nd :datasets

# %%
b = pd.read_csv(r'/home/sunil/Desktop/np/datasets/Sales_April_2019.csv')
b
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df2 = b.iloc[:,:1]
df2
# Out:
#       Order ID
# 0       176558
# 1          NaN
# 2       176559
# 3       176560
# 4       176560
# ...        ...
# 18378   194090
# 18379   194091
# 18380   194092
# 18381   194093
# 18382   194094
#
# [18383 rows x 1 columns]

# %% [markdown]
# # joining

# %%
df3  = df2.join(df1)
df3
# Out:
#       Order ID InvoiceNo                          Description  Quantity  \
# 0       176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          NaN    536365                  WHITE METAL LANTERN         6
# 2       176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 18378   194090    537822         RED RETROSPOT SUGAR JAM BOWL         6
# 18379   194091    537822  SET/5 RED RETROSPOT LID GLASS BOWLS         6
# 18380   194092    537822             RED RETROSPOT CAKE STAND         2
# 18381   194093    537822           RED RETROSPOT PUDDING BOWL         4
# 18382   194094    537822             RETROSPOT LARGE MILK JUG         3
#
#                InvoiceDate  UnitPrice
# 0      2010-12-01 08:26:00       2.55
# ...

# %%
c = pd.read_csv(r'/home/sunil/Desktop/np/datasets/super.csv')
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df4 = c.iloc[:,9:13]
df4
# Out:
#          Total       Date   Time      Payment
# 0     548.9715   1/5/2019  13:08      Ewallet
# 1      80.2200   3/8/2019  10:29         Cash
# 2     340.5255   3/3/2019  13:23  Credit card
# 3     489.0480  1/27/2019  20:33      Ewallet
# 4     634.3785   2/8/2019  10:37      Ewallet
# ..         ...        ...    ...          ...
# 995    42.3675  1/29/2019  13:46      Ewallet
# 996  1022.4900   3/2/2019  17:16      Ewallet
# 997    33.4320   2/9/2019  13:22         Cash
# 998    69.1110  2/22/2019  15:33         Cash
# 999   649.2990  2/18/2019  13:28         Cash
#
# [1000 rows x 4 columns]

# %%
# print(*,"abede".center(6),'*',sept='')

# %%
df5  = df3.join(df4)
df5
# Out:
#       Order ID InvoiceNo                          Description  Quantity  \
# 0       176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          NaN    536365                  WHITE METAL LANTERN         6
# 2       176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 18378   194090    537822         RED RETROSPOT SUGAR JAM BOWL         6
# 18379   194091    537822  SET/5 RED RETROSPOT LID GLASS BOWLS         6
# 18380   194092    537822             RED RETROSPOT CAKE STAND         2
# 18381   194093    537822           RED RETROSPOT PUDDING BOWL         4
# 18382   194094    537822             RETROSPOT LARGE MILK JUG         3
#
#                InvoiceDate  UnitPrice     Total       Date   Time      Payment
# ...

# %%
df5.drop(["Time"],axis=1)
# Out:
#       Order ID InvoiceNo                          Description  Quantity  \
# 0       176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          NaN    536365                  WHITE METAL LANTERN         6
# 2       176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 18378   194090    537822         RED RETROSPOT SUGAR JAM BOWL         6
# 18379   194091    537822  SET/5 RED RETROSPOT LID GLASS BOWLS         6
# 18380   194092    537822             RED RETROSPOT CAKE STAND         2
# 18381   194093    537822           RED RETROSPOT PUDDING BOWL         4
# 18382   194094    537822             RETROSPOT LARGE MILK JUG         3
#
#                InvoiceDate  UnitPrice     Total       Date      Payment
# ...

# %%
d = pd.read_csv(r'/home/sunil/Desktop/np/datasets/Accounts-Receivable.csv')
d.head()
# Out:
#    countryCode  customerID PaperlessDate  invoiceNumber InvoiceDate  \
# 0          391  0379-NEVHP      4/6/2013         611365    1/2/2013
# 1          406  8976-AMJEO      3/3/2012        7900770   1/26/2013
# 2          391  2820-XGXSB     1/26/2012        9231909    7/3/2013
# 3          406  9322-YCTQO      4/6/2012        9888306   2/10/2013
# 4          818  6627-ELFBK    11/26/2012       15752855  10/25/2012
#
#       DueDate  InvoiceAmount Disputed SettledDate PaperlessBill  DaysToSettle  \
# 0    2/1/2013          55.94       No   1/15/2013         Paper            13
# 1   2/25/2013          61.74      Yes    3/3/2013    Electronic            36
# 2    8/2/2013          65.88       No    7/8/2013    Electronic             5
# 3   3/12/2013         105.92       No   3/17/2013    Electronic            35
# 4  11/24/2012          72.27      Yes  11/28/2012         Paper            34
#
#    DaysLate
# 0         0
# 1         6
# 2         0
# 3         5
# 4         4

# %%
# df6 = d.drop(["countryCode","customerID","PaperlessDate","invoiceNumber","InvoiceDate","PaperlessBill","Disputed","SettledDate","DaysToSettle","DaysLate"],axis=1)
# df6
df6 = d.iloc[:,5:6]
df6
# Out:
#          DueDate
# 0       2/1/2013
# 1      2/25/2013
# 2       8/2/2013
# 3      3/12/2013
# 4     11/24/2012
# ...          ...
# 2461  11/17/2013
# 2462  10/19/2012
# 2463    8/1/2012
# 2464   5/27/2012
# 2465    8/3/2013
#
# [2466 rows x 1 columns]

# %%
df7  = df5.join(df6)
df7.head()
# Out:
#   Order ID InvoiceNo                          Description  Quantity  \
# 0   176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      NaN    536365                  WHITE METAL LANTERN         6
# 2   176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3   176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice     Total       Date   Time      Payment  \
# 0  2010-12-01 08:26:00       2.55  548.9715   1/5/2019  13:08      Ewallet
# 1  2010-12-01 08:26:00       3.39   80.2200   3/8/2019  10:29         Cash
# 2  2010-12-01 08:26:00       2.75  340.5255   3/3/2019  13:23  Credit card
# 3  2010-12-01 08:26:00       3.39  489.0480  1/27/2019  20:33      Ewallet
# 4  2010-12-01 08:26:00       3.39  634.3785   2/8/2019  10:37      Ewallet
#
#       DueDate
# 0    2/1/2013
# 1   2/25/2013
# 2    8/2/2013
# 3   3/12/2013
# 4  11/24/2012

# %%
df7.shape
# Out:
# (18383, 11)

# %%
df7.loc[:,["Date","Order ID","InvoiceNo","InvoiceDate","Description","Quantity","UnitPrice","DueDate","Payment","Total"]]
# Out:
#             Date Order ID InvoiceNo          InvoiceDate  \
# 0       1/5/2019   176558    536365  2010-12-01 08:26:00
# 1       3/8/2019      NaN    536365  2010-12-01 08:26:00
# 2       3/3/2019   176559    536365  2010-12-01 08:26:00
# 3      1/27/2019   176560    536365  2010-12-01 08:26:00
# 4       2/8/2019   176560    536365  2010-12-01 08:26:00
# ...          ...      ...       ...                  ...
# 18378        NaN   194090    537822  2010-12-08 14:22:00
# 18379        NaN   194091    537822  2010-12-08 14:22:00
# 18380        NaN   194092    537822  2010-12-08 14:22:00
# 18381        NaN   194093    537822  2010-12-08 14:22:00
# 18382        NaN   194094    537822  2010-12-08 14:22:00
#
#                                Description  Quantity  UnitPrice     DueDate  \
# 0       WHITE HANGING HEART T-LIGHT HOLDER         6       2.55    2/1/2013
# 1                      WHITE METAL LANTERN         6       3.39   2/25/2013
# ...

# %%
df7.isnull().sum()  #total number of null values
# Out:
# Order ID          59
# InvoiceNo          0
# Description       61
# Quantity           0
# InvoiceDate        0
# UnitPrice          0
# Total          17383
# Date           17383
# Time           17383
# Payment        17383
# DueDate        15917
# dtype: int64

# %%
df = df7.dropna()
df
# Out:
#     Order ID InvoiceNo                          Description  Quantity  \
# 0     176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2     176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3     176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     176561    536365         SET 7 BABUSHKA NESTING BOXES         2
# ..       ...       ...                                  ...       ...
# 995   177504    536520                HEART OF WICKER SMALL         1
# 996   177505    536520             SKULLS SQUARE TISSUE BOX         1
# 997   177506    536520      PINK PAISLEY SQUARE TISSUE BOX          1
# 998   177506    536520         PACK OF 6 HANDBAG GIFT BOXES         1
# 999   177507    536520           TOAST ITS - HAPPY BIRTHDAY         2
#
#              InvoiceDate  UnitPrice      Total       Date   Time      Payment  \
# ...

# %%
df.shape
# Out:
# (996, 11)

# %%
df.head()
# Out:
#   Order ID InvoiceNo                          Description  Quantity  \
# 0   176558    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2   176559    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3   176560    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   176560    536365       RED WOOLLY HOTTIE WHITE HEART.         6
# 5   176561    536365         SET 7 BABUSHKA NESTING BOXES         2
#
#            InvoiceDate  UnitPrice     Total       Date   Time      Payment  \
# 0  2010-12-01 08:26:00       2.55  548.9715   1/5/2019  13:08      Ewallet
# 2  2010-12-01 08:26:00       2.75  340.5255   3/3/2019  13:23  Credit card
# 3  2010-12-01 08:26:00       3.39  489.0480  1/27/2019  20:33      Ewallet
# 4  2010-12-01 08:26:00       3.39  634.3785   2/8/2019  10:37      Ewallet
# 5  2010-12-01 08:26:00       7.65  627.6165  3/25/2019  18:30      Ewallet
#
#       DueDate
# 0    2/1/2013
# 2    8/2/2013
# 3   3/12/2013
# 4  11/24/2012
# 5   2/26/2012

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           343
# Credit card    308
# Name: Payment, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,-2], df['Payment'], test_size = 0.20, random_state = 0)

# %%
X_train
# Out:
# 823           Cash
# 883        Ewallet
# 114    Credit card
# 611           Cash
# 38         Ewallet
#           ...
# 839        Ewallet
# 193        Ewallet
# 632    Credit card
# 561    Credit card
# 687           Cash
# Name: Payment, Length: 796, dtype: object

# %%
X_test
# Out:
# 987    Credit card
# 727    Credit card
# 32            Cash
# 999           Cash
# 868    Credit card
#           ...
# 434    Credit card
# 866    Credit card
# 272    Credit card
# 907    Credit card
# 515        Ewallet
# Name: Payment, Length: 200, dtype: object

# %%
y_train
# Out:
# 823           Cash
# 883        Ewallet
# 114    Credit card
# 611           Cash
# 38         Ewallet
#           ...
# 839        Ewallet
# 193        Ewallet
# 632    Credit card
# 561    Credit card
# 687           Cash
# Name: Payment, Length: 796, dtype: object

# %%
y_test
# Out:
# 987    Credit card
# 727    Credit card
# 32            Cash
# 999           Cash
# 868    Credit card
#           ...
# 434    Credit card
# 866    Credit card
# 272    Credit card
# 907    Credit card
# 515        Ewallet
# Name: Payment, Length: 200, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Credit card','Cash','Ewallet']])

# %%
df['Payment'].reshape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 df['Payment'].reshape
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 oe.fit(X_train)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:1258, in OrdinalEncoder.fit(self, X, y)
#    1251     raise TypeError(
#    1252         "unknown_value should only be set when "
#    1253         "handle_unknown is 'use_encoded_value', "
#    1254         f"got {self.unknown_value}."
#    1255     )
#    1257 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1258 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    1260 if self.handle_unknown == "use_encoded_value":
#    1261     for feature_cats in self.categories_:
#
# File ~/.local/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:74, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts)
# ...
